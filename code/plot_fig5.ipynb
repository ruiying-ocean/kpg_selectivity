# %%
from cgeniepy.ecology import EcoModel
import pandas as pd

m = EcoModel("../model/muffin.u067bc.PO4.8P8Z.EXP6")
d13c = m.get_ts("biogem_series_ocn_DIC_13C.res")

# %%
m = EcoModel("../model/muffin.u067bc.PO4.8P8Z.EXP5")
d13c = m.get_ts("biogem_series_ocn_DIC_13C.res")
d13c['delta'] = d13c['surface DIC_13C (o/oo)'] -d13c['benthic [> 2000 m] DIC_13C (o/oo)']
d13c.plot(x= 'time (yr)',y='delta')
# Out:
# <Axes: xlabel='time (yr)'>

# %%
import seaborn as sns

d13c['delta'] = d13c['surface DIC_13C (o/oo)'] -d13c['benthic [> 2000 m] DIC_13C (o/oo)']
d13c.plot(x= 'time (yr)',y='delta')
# Out:
# <Axes: xlabel='time (yr)'>
